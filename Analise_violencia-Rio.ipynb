# %% [markdown]
# # Importando bibliotecas

# %%
import pandas as pd

# %% [markdown]
# # Lendo os dados

# %%
dados = pd.read_excel('BaseEstadoTaxaMes.xlsx', delimiter='\t')

# %%
dados.head(21)
# Out:
#      ano  mes  mes_ano hom_doloso lesao_corp_morte latrocinio  \
# 0   2003    1  2003m01       4,01             0,04       0,14
# 1   2003    2  2003m02       3,97             0,03       0,08
# 2   2003    3  2003m03       4,17             0,03       0,11
# 3   2003    4  2003m04       3,98             0,07        0,1
# 4   2003    5  2003m05       4,08             0,04       0,14
# 5   2003    6  2003m06       3,72             0,01        0,1
# 6   2003    7  2003m07       3,55             0,05       0,11
# 7   2003    8  2003m08       3,37             0,03       0,07
# 8   2003    9  2003m09       3,45             0,03       0,11
# 9   2003   10  2003m10       3,29             0,01       0,11
# 10  2003   11  2003m11       3,56             0,02       0,08
# 11  2003   12  2003m12       3,72             0,01       0,08
# 12  2004    1  2004m01       3,89             0,03       0,08
# 13  2004    2  2004m02       3,64             0,03       0,11
# ...

# %% [markdown]
# # Informações do Data Frame

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 215 entries, 0 to 214
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   ano                         215 non-null    int64
#  1   mes                         215 non-null    int64
#  2   mes_ano                     215 non-null    object
#  3   hom_doloso                  215 non-null    object
#  4   lesao_corp_morte            215 non-null    object
#  5   latrocinio                  215 non-null    object
#  6   hom_por_interv_policial     215 non-null    object
#  7   letalidade_violenta         215 non-null    object
#  8   tentat_hom                  215 non-null    object
#  9   lesao_corp_dolosa           215 non-null    object
#  10  estupro                     215 non-null    object
#  11  hom_culposo                 215 non-null    object
#  12  lesao_corp_culposa          215 non-null    object
# ...

# %% [markdown]
# # Resumo estatístico dos campos categoricos

# %%
dados.describe(include='O')
# Out:
#         mes_ano  hom_doloso lesao_corp_morte latrocinio  \
# count       215         215              215        215
# unique      215         144                8         20
# top     2013m03           2             0,01       0,08
# freq          1           4               74         27
#
#        hom_por_interv_policial letalidade_violenta tentat_hom  \
# count                      215                 215        215
# unique                      81                 154        126
# top                       0,23                2,88       2,18
# freq                         9                   4          6
#
#        lesao_corp_dolosa estupro hom_culposo  ... aaapai   cmp  cmba ameaca  \
# count                215     215         215  ...    179   179   179    215
# unique               201     130          89  ...    144   158    79    207
# top                44,38    1,72        1,28  ...   1,77  8,08  0,28  42,07
# ...

# %% [markdown]
# # Seleção de algumas colunas especifícas para análise

# %% [markdown]
# # Indice da taxa de latrocínio de janeiro de 2003 a junho de 2005.

# %%
dados[['mes_ano', 'latrocinio']].head(30)
# Out:
#     mes_ano latrocinio
# 0   2003m01       0,14
# 1   2003m02       0,08
# 2   2003m03       0,11
# 3   2003m04        0,1
# 4   2003m05       0,14
# 5   2003m06        0,1
# 6   2003m07       0,11
# 7   2003m08       0,07
# 8   2003m09       0,11
# 9   2003m10       0,11
# 10  2003m11       0,08
# 11  2003m12       0,08
# 12  2004m01       0,08
# 13  2004m02       0,11
# 14  2004m03       0,11
# 15  2004m04       0,14
# 16  2004m05       0,12
# 17  2004m06       0,09
# 18  2004m07        0,1
# 19  2004m08       0,09
# 20  2004m09       0,14
# 21  2004m10       0,09
# 22  2004m11       0,12
# 23  2004m12       0,05
# 24  2005m01       0,13
# 25  2005m02       0,08
# 26  2005m03       0,17
# 27  2005m04        0,1
# 28  2005m05       0,13
# 29  2005m06       0,11

# %% [markdown]
# # Indice da taxa de homicídio doloso de janeiro de 2003 a junho de 2005.

# %%
dados[['mes_ano','hom_doloso']].head(30)
# Out:
#     mes_ano hom_doloso
# 0   2003m01       4,01
# 1   2003m02       3,97
# 2   2003m03       4,17
# 3   2003m04       3,98
# 4   2003m05       4,08
# 5   2003m06       3,72
# 6   2003m07       3,55
# 7   2003m08       3,37
# 8   2003m09       3,45
# 9   2003m10       3,29
# 10  2003m11       3,56
# 11  2003m12       3,72
# 12  2004m01       3,89
# 13  2004m02       3,64
# 14  2004m03       3,56
# 15  2004m04       3,46
# 16  2004m05       4,07
# 17  2004m06       3,38
# 18  2004m07       3,37
# 19  2004m08       3,47
# 20  2004m09       3,37
# 21  2004m10       3,47
# 22  2004m11       3,79
# 23  2004m12       3,62
# 24  2005m01       4,03
# 25  2005m02        4,1
# 26  2005m03       4,52
# 27  2005m04       3,48
# 28  2005m05       3,71
# 29  2005m06       3,22

# %% [markdown]
# # Indice da taxa de morte por lesão corporal de janeiro de 2003 a junho de 2005.

# %%
dados[['mes_ano','lesao_corp_morte']].head(30)
# Out:
#     mes_ano lesao_corp_morte
# 0   2003m01             0,04
# 1   2003m02             0,03
# 2   2003m03             0,03
# 3   2003m04             0,07
# 4   2003m05             0,04
# 5   2003m06             0,01
# 6   2003m07             0,05
# 7   2003m08             0,03
# 8   2003m09             0,03
# 9   2003m10             0,01
# 10  2003m11             0,02
# 11  2003m12             0,01
# 12  2004m01             0,03
# 13  2004m02             0,03
# 14  2004m03             0,01
# 15  2004m04             0,01
# 16  2004m05             0,03
# 17  2004m06             0,01
# 18  2004m07             0,01
# 19  2004m08             0,04
# 20  2004m09             0,01
# 21  2004m10             0,04
# 22  2004m11             0,03
# 23  2004m12             0,01
# 24  2005m01             0,04
# 25  2005m02             0,03
# 26  2005m03             0,01
# 27  2005m04             0,02
# 28  2005m05             0,04
# 29  2005m06             0,03

# %% [markdown]
# # Indice da taxa mensal de violência de janeiro de 2003 a junho de 2005.

# %%
dados[['mes_ano', 'tentat_hom','lesao_corp_dolosa','estupro','hom_culposo', 'pessoas_desaparecidas','roubo_rua','registro_ocorrencias']].head(30)
# Out:
#     mes_ano tentat_hom lesao_corp_dolosa estupro hom_culposo  \
# 0   2003m01       2,48             46,94    1,67        1,11
# 1   2003m02       2,46             48,32     1,5        1,28
# 2   2003m03       2,26             47,43    1,61        1,28
# 3   2003m04       2,02             43,84    1,46        1,41
# 4   2003m05       2,59             39,77    1,29        1,55
# 5   2003m06       2,15             42,88    1,35        1,61
# 6   2003m07       2,76             41,09    1,27        1,32
# 7   2003m08       2,69              39,3    1,38        1,26
# 8   2003m09       1,83              40,8    1,46        1,23
# 9   2003m10       2,32             41,65    1,41        1,26
# 10  2003m11       2,18             46,13    1,56        1,17
# 11  2003m12       2,19             51,55    1,49        1,62
# 12  2004m01       2,04             44,12    1,66        1,26
# 13  2004m02       2,13             43,48    1,34         1,2
# ...

# %%
# Máximo de valores de cada coluna do conjunto de dados
dados.max()
# Out:
# ano                             2020
# mes                               12
# mes_ano                      2020m11
# latrocinio                       0,2
# estupro                         3,45
# roubo_veiculo                    NaN
# roubo_celular                   9,72
# roubo_conducao_saque            0,25
# furto_veiculos                   NaN
# extorsao                        1,79
# apreensao_drogas                9,99
# recuperacao_veiculos             NaN
# pessoas_desaparecidas           3,83
# pol_militares_mortos_serv        NaN
# pol_civis_mortos_serv            NaN
# fase                               3
# dtype: object

# %%
# Mínimo dos valores de cada coluna do conjunto de dados
dados.min()
# Out:
# ano                             2003
# mes                                1
# mes_ano                      2003m01
# latrocinio                      0,01
# estupro                         1,27
# roubo_veiculo                    NaN
# roubo_celular                   1,85
# roubo_conducao_saque            0,01
# furto_veiculos                   NaN
# extorsao                        0,16
# apreensao_drogas               10,03
# recuperacao_veiculos             NaN
# pessoas_desaparecidas           1,03
# pol_militares_mortos_serv        NaN
# pol_civis_mortos_serv            NaN
# fase                               2
# dtype: object

# %%
# Indice da taxa mensal de roubo de celular no Estado do Rio de Janeiro de janeiro 
#de 2003 a abril de 2006.
dados[['mes_ano','roubo_celular']].head(40)
# Out:
#     mes_ano roubo_celular
# 0   2003m01          6,58
# 1   2003m02          6,55
# 2   2003m03          6,68
# 3   2003m04          6,85
# 4   2003m05           7,3
# 5   2003m06          6,55
# 6   2003m07          6,86
# 7   2003m08          7,01
# 8   2003m09           8,1
# 9   2003m10           8,6
# 10  2003m11          7,61
# 11  2003m12          7,68
# 12  2004m01          8,78
# 13  2004m02          7,24
# 14  2004m03          9,37
# 15  2004m04           6,7
# 16  2004m05          9,39
# 17  2004m06          9,22
# 18  2004m07          7,13
# 19  2004m08          5,32
# 20  2004m09          3,16
# 21  2004m10          2,58
# 22  2004m11           2,9
# 23  2004m12          2,53
# 24  2005m01          2,92
# 25  2005m02          2,72
# 26  2005m03          3,66
# 27  2005m04           3,9
# 28  2005m05          4,12
# 29  2005m06          4,12
# 30  2005m07          4,03
# 31  2005m08          4,62
# 32  2005m09          3,71
# 33  2005m10          4,22
# ...

# %%
# Taxa mensal do indice de estupros e homicídios dolosos no Estado do Rio de Janeiro de janeiro
# de 2003 a fevereiro de 2007
dados[['mes_ano','estupro','hom_doloso']].head(50)
# Out:
#     mes_ano estupro hom_doloso
# 0   2003m01    1,67       4,01
# 1   2003m02     1,5       3,97
# 2   2003m03    1,61       4,17
# 3   2003m04    1,46       3,98
# 4   2003m05    1,29       4,08
# 5   2003m06    1,35       3,72
# 6   2003m07    1,27       3,55
# 7   2003m08    1,38       3,37
# 8   2003m09    1,46       3,45
# 9   2003m10    1,41       3,29
# 10  2003m11    1,56       3,56
# 11  2003m12    1,49       3,72
# 12  2004m01    1,66       3,89
# 13  2004m02    1,34       3,64
# 14  2004m03    1,74       3,56
# 15  2004m04    1,61       3,46
# 16  2004m05    1,31       4,07
# 17  2004m06    1,45       3,38
# 18  2004m07     1,3       3,37
# 19  2004m08    1,84       3,47
# 20  2004m09    1,88       3,37
# 21  2004m10    1,81       3,47
# 22  2004m11    1,86       3,79
# 23  2004m12    1,72       3,62
# 24  2005m01    2,22       4,03
# 25  2005m02    1,72        4,1
# 26  2005m03     2,1       4,52
# 27  2005m04    1,91       3,48
# 28  2005m05    2,02       3,71
# ...
